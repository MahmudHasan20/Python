# %%
import pandas as pd
import numpy as np

# %%
 s = pd.Series([12,-4,7,9])

# %%
s
# Out:
# 0    12
# 1    -4
# 2     7
# 3     9
# dtype: int64

# %%
 s = pd.Series([12,-4,7,9], index=['a','b','c','d'])
 s
# Out:
# a    12
# b    -4
# c     7
# d     9
# dtype: int64

# %%
s.values
# Out:
# array([12, -4,  7,  9])

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s/2
# Out:
# a    6.0
# b   -2.0
# c    3.5
# d    4.5
# dtype: float64

# %%
np.log(s)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# a    2.484907
# b         NaN
# c    1.945910
# d    2.197225
# dtype: float64

# %%
data = {'color' : ['blue','green','yellow','red','white'],
 'object' : ['ball','pen','pencil','paper','mug'],
 'price' : [1.2,1.0,0.6,0.9,1.7]}

# %%
 frame = pd.DataFrame(data)
 frame
# Out:
#     color  object  price
# 0    blue    ball    1.2
# 1   green     pen    1.0
# 2  yellow  pencil    0.6
# 3     red   paper    0.9
# 4   white     mug    1.7

# %%
 frame2 = pd.DataFrame(data, columns=['object','price'])

# %%
frame2
# Out:
#    object  price
# 0    ball    1.2
# 1     pen    1.0
# 2  pencil    0.6
# 3   paper    0.9
# 4     mug    1.7

# %%
 s1 = pd.Series([3,2,5,1],['white','yellow','green','blue'])
 s2 = pd.Series([1,4,7,2,1],['white','yellow','black','blue','brown'])

# %%
s1 + s2
# Out:
# black     NaN
# blue      3.0
# brown     NaN
# green     NaN
# white     4.0
# yellow    6.0
# dtype: float64

# %%
frame1 = pd.DataFrame(np.arange(16).reshape((4,4)),index=['red','blue','yellow','white'],columns=['ball','pen','pencil','paper'])
frame2 = pd.DataFrame(np.arange(12).reshape((4,3)),index=['blue','green','white','yellow'],columns=['mug','pen','ball'])

# %%
frame1
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# frame1['ball'].plot(kind='hist', bins=20, title='ball')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# frame1['pen'].plot(kind='hist', bins=20, title='pen')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# frame1['pencil'].plot(kind='hist', bins=20, title='pencil')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# frame1['paper'].plot(kind='hist', bins=20, title='paper')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# frame1.plot(kind='scatter', x='ball', y='pen', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# frame1.plot(kind='scatter', x='pen', y='pencil', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# frame1.plot(kind='scatter', x='pencil', y='paper', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['ball']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'ball'}, axis=1)
#               .sort_values('ball', ascending=True))
#   xs = counted['ball']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = frame1.sort_values('ball', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('ball')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['pen']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'pen'}, axis=1)
#               .sort_values('pen', ascending=True))
#   xs = counted['pen']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = frame1.sort_values('pen', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('pen')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['pencil']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'pencil'}, axis=1)
#               .sort_values('pencil', ascending=True))
#   xs = counted['pencil']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = frame1.sort_values('pencil', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('pencil')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['paper']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'paper'}, axis=1)
#               .sort_values('paper', ascending=True))
#   xs = counted['paper']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = frame1.sort_values('paper', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('paper')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# frame1['ball'].plot(kind='line', figsize=(8, 4), title='ball')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# frame1['pen'].plot(kind='line', figsize=(8, 4), title='pen')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# frame1['pencil'].plot(kind='line', figsize=(8, 4), title='pencil')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# frame1['paper'].plot(kind='line', figsize=(8, 4), title='paper')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
frame2
# Out:
#         mug  pen  ball
# blue      0    1     2
# green     3    4     5
# white     6    7     8
# yellow    9   10    11

# %%
frame1.add(frame2)
# Out:
#         ball  mug  paper   pen  pencil
# blue     6.0  NaN    NaN   6.0     NaN
# green    NaN  NaN    NaN   NaN     NaN
# red      NaN  NaN    NaN   NaN     NaN
# white   20.0  NaN    NaN  20.0     NaN
# yellow  19.0  NaN    NaN  19.0     NaN

# %%
frame = pd.DataFrame(np.arange(16).reshape((4,4)),index=['red','blue','yellow','white'],columns=['ball','pen','pencil','paper'])

# %%
frame
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
 frame.sum()
# Out:
# ball      24
# pen       28
# pencil    32
# paper     36
# dtype: int64

# %%
frame.mean()
# Out:
# ball      6.0
# pen       7.0
# pencil    8.0
# paper     9.0
# dtype: float64

# %%
 frame.describe()
# Out:
#             ball        pen     pencil      paper
# count   4.000000   4.000000   4.000000   4.000000
# mean    6.000000   7.000000   8.000000   9.000000
# std     5.163978   5.163978   5.163978   5.163978
# min     0.000000   1.000000   2.000000   3.000000
# 25%     3.000000   4.000000   5.000000   6.000000
# 50%     6.000000   7.000000   8.000000   9.000000
# 75%     9.000000  10.000000  11.000000  12.000000
# max    12.000000  13.000000  14.000000  15.000000

# %%
seq2 = pd.Series([3,4,3,4,5,4,3,2],['2006','2007','2008','2009','2010','2011','2012','2013'])

# %%
 seq = pd.Series([1,2,3,4,4,3,2,1],['2006','2007','2008',
'2009','2010','2011','2012','2013'])

# %%
seq.corr(seq2)
# Out:
# 0.7745966692414835

# %%
 seq.cov(seq2)
# Out:
# 0.8571428571428571
