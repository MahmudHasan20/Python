# %% [markdown]
# **CSV File upload and works**

# %%
import pandas as pd
csvframe=pd.read_csv('salary_data.csv')

# %% [markdown]
# **CSV frame**

# %%
csvframe
# Out:
#    YearsExperience,Salary
# 0             0,1.1,39343
# 1             1,1.3,46205
# 2             2,1.5,37731
# 3               3,2,45731
# 4             4,2.2,51731
# 5             5,2.9,47731
# 6               6,3,35731
# 7             7,3.2,56731
# 8             8,3.2,60152
# 9             9,3.7,66000
# 10           10,3.9,73250
# 11             11,4,78152
# 12             12,4,80453
# 13           13,4.1,40125
# 14           14,4.5,82153
# 15           15,4.9,84163
# 16             16,5,86540
# 17           17,5.1,90125
# 18          18,5.3,100789
# 19          19,5.9,108520
# 20            20,6,106258
# 21          21,6.8,112360
# 22            22,7,118752
# 23          23,7.9,110470
# 24          24,8.2,105693
# 25          25,8.7,145632
# 26            26,9,117896
# 27          27,9.5,176321
# 28          28,9.6,156320
# 29         29,10.3,135401
# 30         30,1.05,120369

# %% [markdown]
# **Plot Show**

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])

plt.show()

# %%
 plt.axis([0,5,0,20])
 plt.plot([1,2,3,4],[1,4,9,16],'ro')
 plt.title('My first plot')
 plt.xlabel('Counting')
 plt.ylabel('Square values')
 plt.text(1,1.5,'First')
 plt.text(2,4.5,'Second')
 plt.text(3,9.5,'Third')
 plt.text(4,16.5,'Fourth')
 plt.grid(True)
 plt.legend(['First series'])
 plt.show()

# %%
import math
import numpy as np

t = np.arange(0,2.5,0.1)
y1 = np.sin(math.pi*t)
y2 = np.sin(math.pi*t+math.pi/2)
y3 = np.sin(math.pi*t-math.pi/2)

plt.plot(t,y1,'b*',t,y2,'g^',t,y3,'ys')
# Out:
# [<matplotlib.lines.Line2D at 0x7ff3708d71c0>,
#  <matplotlib.lines.Line2D at 0x7ff3708d7190>,
#  <matplotlib.lines.Line2D at 0x7ff3708d7340>]

# %%
plt.plot(t,y1,'b--',t,y2,'g',t,y3,'r-.')
# Out:
# [<matplotlib.lines.Line2D at 0x7ff37096dba0>,
#  <matplotlib.lines.Line2D at 0x7ff37096db70>,
#  <matplotlib.lines.Line2D at 0x7ff37096dc90>]

# %% [markdown]
# **Horizontal Subplot**

# %%
t = np.arange(0,5,0.1)

y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)

plt.subplot(211)
plt.plot(t,y1,'b-.')

plt.subplot(212)
plt.plot(t,y2,'r--')

# %% [markdown]
# **Vertica Subplot**

# %%
t = np.arange(0.,1.,0.05)

y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)

plt.subplot(121)
plt.plot(t,y1,'b-.')

plt.subplot(122)
plt.plot(t,y2,'r--')

# %%
pop = np.random.randint(0,100,100)
pop
# Out:
# array([40,  7, 35, 62, 85, 22, 19, 73, 15, 89, 99, 52, 41, 12,  4, 55, 16,
#        27, 34, 30, 73, 90, 77, 59, 51, 33, 80, 66, 69, 31, 81, 30, 67, 81,
#        15, 67, 35, 35, 13, 14, 75, 21, 35, 13, 45, 35, 73, 47, 38, 43, 61,
#        89, 38, 35, 79,  6, 17, 72,  8,  1, 64, 71, 64, 71, 14, 23, 63, 24,
#        69, 12, 30, 68, 67, 93, 60, 86, 34, 49, 75, 97, 29, 79, 83, 78, 48,
#        47, 21, 65, 40, 75, 34,  3, 92, 46, 99, 52,  4, 63, 60, 33])

# %% [markdown]
# **Historam**

# %%
n,bins,patches = plt.hist(pop,bins=20)

# %%
index = np.arange(5)
values1 = [5,7,3,4,6]
std1 = [0.8,1,0.4,0.9,1.3]
plt.bar(index,values1,yerr=std1,error_kw={'ecolor':'0.1','capsize':6},alpha=0.7,label='First')
plt.xticks(index+0.4,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x7ff37069f160>,
#   <matplotlib.axis.XTick at 0x7ff37069f130>,
#   <matplotlib.axis.XTick at 0x7ff37069f040>,
#   <matplotlib.axis.XTick at 0x7ff3705085e0>,
#   <matplotlib.axis.XTick at 0x7ff370509090>],
#  [Text(0.4, 0, 'A'),
#   Text(1.4, 0, 'B'),
#   Text(2.4, 0, 'C'),
#   Text(3.4, 0, 'D'),
#   Text(4.4, 0, 'E')])

# %%
index = np.arange(5)
values1 = [5,7,3,4,6]
std1 = [0.8,1,0.4,0.9,1.3]
plt.barh(index,values1,xerr=std1,error_kw={'ecolor':'0.1','capsize':6},alpha=0.7,label='First')
plt.yticks(index+0.4,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.YTick at 0x7ff370541750>,
#   <matplotlib.axis.YTick at 0x7ff3705410f0>,
#   <matplotlib.axis.YTick at 0x7ff370540130>,
#   <matplotlib.axis.YTick at 0x7ff370576080>,
#   <matplotlib.axis.YTick at 0x7ff370576b30>],
#  [Text(0, 0.4, 'A'),
#   Text(0, 1.4, 'B'),
#   Text(0, 2.4, 'C'),
#   Text(0, 3.4, 'D'),
#   Text(0, 4.4, 'E')])

# %%
data = {'series1':[1,3,4,3,5],'series2':[2,4,5,2,4],'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
df.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **Pie Chart**

# %%
import matplotlib.pyplot as plt

labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']

plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%',startangle=180)
plt.axis('equal')
# Out:
# (-1.0999999532279854,
#  1.0999990177876953,
#  -1.0999999532281324,
#  1.0999990177907812)

# %%
df['series2'].plot(kind='pie',figsize=(6,6))
# Out:
# <Axes: ylabel='series2'>

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

# Creating dataset
np.random.seed(10)

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize =(10, 7))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()

# %%
import matplotlib.pyplot as plt

x =[5, 7, 8, 7, 2, 17, 2, 9,4, 11, 12, 9, 6]
y =[99, 86, 87, 88, 100, 86,103, 87, 94, 78, 77, 85, 86]

plt.scatter(x, y, c ="blue")

# To show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# dataset-1
x1 = [89, 43, 36, 36, 95, 10,66, 34, 38, 20]
y1 = [21, 46, 3, 35, 67, 95, 53, 72, 58, 10]

# dataset2
x2 = [26, 29, 48, 64, 6, 5,36, 66, 72, 40]
y2 = [26, 34, 90, 33, 38,20, 56, 2, 47, 15]

plt.scatter(x1, y1, c ="red")
plt.scatter(x2, y2, c ="green")

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
